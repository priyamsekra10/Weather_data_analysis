# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import MultipleLocator

import seaborn as sns
# %matplotlib inline

# %%
weather = pd.read_csv('data.csv')

# %%
weather
# Out:
#            date  maxtemp  mintemp  meantemp  precip  meanpressure  humidity  \
# 0    01-01-2021       24       12        18     0.0       1015.67       100
# 1    02-01-2021       23        9        16     0.0       1018.75       100
# 2    03-01-2021       23       10        16     0.0       1019.15       100
# 3    04-01-2021       24       10        17     0.0       1016.93       100
# 4    05-01-2021       25       10        18     0.0       1015.19       100
# ..          ...      ...      ...       ...     ...           ...       ...
# 359  27-12-2021       25        9        17     0.0       1017.88        71
# 360  28-12-2021       25        9        17     0.0       1017.33        75
# 361  29-12-2021       25       10        18     0.0       1017.63        66
# 362  30-12-2021       24        9        16     0.0       1017.87        67
# 363  31-12-2021       22        9        16     0.0       1016.41        67
#
#      meandewpt
# 0           11
# 1           13
# ...

# %%
weather.head()
# Out:
#          date  maxtemp  mintemp  meantemp  precip  meanpressure  humidity  \
# 0  01-01-2021       24       12        18     0.0       1015.67       100
# 1  02-01-2021       23        9        16     0.0       1018.75       100
# 2  03-01-2021       23       10        16     0.0       1019.15       100
# 3  04-01-2021       24       10        17     0.0       1016.93       100
# 4  05-01-2021       25       10        18     0.0       1015.19       100
#
#    meandewpt
# 0         11
# 1         13
# 2         12
# 3         13
# 4         11

# %%
weather.shape
# Out:
# (364, 8)

# %%
weather.isnull()
# Out:
#       date  maxtemp  mintemp  meantemp  precip  meanpressure  humidity  \
# 0    False    False    False     False   False         False     False
# 1    False    False    False     False   False         False     False
# 2    False    False    False     False   False         False     False
# 3    False    False    False     False   False         False     False
# 4    False    False    False     False   False         False     False
# ..     ...      ...      ...       ...     ...           ...       ...
# 359  False    False    False     False   False         False     False
# 360  False    False    False     False   False         False     False
# 361  False    False    False     False   False         False     False
# 362  False    False    False     False   False         False     False
# 363  False    False    False     False   False         False     False
#
#      meandewpt
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# ...

# %%
sns.heatmap(weather.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## no null values in the data set

# %%
plt.plot(weather.date,weather.meantemp,"b")
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # temperature is minimum around 15th Jan and maximum around 1st June

# %%
plt.plot(weather.date,weather.maxtemp)
plt.plot(weather.date,weather.mintemp)
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)

plt.show()

# %% [markdown]
# # Date VS Daily minimum and maximum temprature

# %%
# plt.plot(weather.meantemp,weather.meanpressure)
# plt.show()

plt.scatter(weather.date,weather.maxtemp)
plt.scatter(weather.date,weather.mintemp)
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # temperature grapf shows a M shaped curve, i.e, temerature increase and decrease 2 times yearly.

# %%
df = weather['maxtemp'] - weather['mintemp']
df
# Out:
# 0      12
# 1      14
# 2      13
# 3      14
# 4      15
#        ..
# 359    16
# 360    16
# 361    15
# 362    15
# 363    13
# Length: 364, dtype: int64

# %%
plt.plot(weather.date,df,"b")
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # The difference in maximum and minimum temerature is very less during the month of july and aug.

# %%
plt.plot(weather.meantemp,weather.meanpressure,"o")
# plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Pressure is inversely proporsnal to temerature

# %%
plt.plot(weather.humidity,weather.meanpressure,"o")
# plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Humidity and pressure shows somewhat direct relationship

# %%
plt.plot(weather.precip,weather.meanpressure,"o")
# plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## The lower the pressure, more the rainfall.

# %%
plt.plot(weather.date,weather.meanpressure,"o")
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Pressure shows a V shaped graph yearly. It is minimun in july, aug.
# ## Hence if a low pressure is created, then it rains.

# %%
plt.plot(weather.meandewpt,weather.meanpressure,"o")
# plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## The dew point is inversely proporsnal to pressure

# %%
plt.plot(weather.meantemp,weather.humidity,"o")
# plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## temperature and humidity are never together low.

# %%
sns.boxplot(weather.meantemp,weather.humidity, data = weather, palette = "rainbow")
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='meantemp', ylabel='humidity'>

# %% [markdown]
# ## The humidity is maximum when the temerature ranges from 25 to 30.

# %%
plt.plot(weather.humidity,weather.precip,'o')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## More the humidity, more the rainfall, or visa versa.

# %%
plt.plot(weather.humidity,weather.meandewpt,'o')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Humidity is directly proporsnal to the dew point.

# %%
plt.plot(weather.date,weather.precip,'o')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Rainfall is maximum in the months of july and aug.

# %%
plt.plot(weather.date,weather.humidity,'o')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Humidity shows a reverse M graph. Hence, whenever temerature increases, humidity decreases. Humidity is minimum in april and may.

# %%
plt.plot(weather.precip,weather.meandewpt,'o')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Mean due point is max when precip is maximum.

# %%
plt.plot(weather.date,weather.meandewpt,'o')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## dewpoint is maximum in the month of aug and sept.

# %%
plt.plot(df,weather.precip,"o")
# plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## When precipitation is maximum, temp difference is minimum.

# %%
sns.pairplot(weather,size=3)
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Pair plot of weather database.

# %%
sns.pairplot(weather,hue= "precip",size=3)
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Multivariate Analysis of weather database.
# ## Pair plot of weather database with respect to precipitation.

# %%
plt.plot(weather.date,weather.precip,'')
plt.gca().xaxis.set_major_locator(MultipleLocator(15))
plt.xticks(rotation = 90)
plt.show()

# %%
sns.jointplot(x = "meantemp", y = "precip", data = weather, kind = 'reg')

# %%
df1 = weather["precip"]
sns.distplot(df1, kde = False, bins = 10)
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='precip'>

# %% [markdown]
# ## There is no precipitation 340 days a year.

# %%
sns.countplot("precip", data = weather)
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='precip', ylabel='count'>

# %%
df1.sum(axis = 0, skipna = True)
# Out:
# 386.7

# %% [markdown]
# ## Total rainfall in 2021: 386.7 mm

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          364 non-null    object
#  1   maxtemp       364 non-null    int64
#  2   mintemp       364 non-null    int64
#  3   meantemp      364 non-null    int64
#  4   precip        364 non-null    float64
#  5   meanpressure  364 non-null    float64
#  6   humidity      364 non-null    int64
#  7   meandewpt     364 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 22.9+ KB

# %%
sns.FacetGrid(weather,hue="meantemp",size=5).map(plt.scatter,"date","precip").add_legend();
plt.show()
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
